# %%
import numpy as np
import torch
torch.set_default_tensor_type('torch.DoubleTensor')
def toCuda(x):
    return x.cuda()
    
x = torch.from_numpy(np.random.randint(1, high=10, size=10))#.float()
xx = torch.from_numpy(np.random.randint(1, high=10, size=10))#.float()
y = torch.from_numpy(np.random.randint(1, high=10, size=10))#.float()
yy = torch.from_numpy(np.random.randint(1, high=10, size=10))#.float()

u = [x, xx, y, yy]
# y = [print(x) for x in u]
# print(uu)

kk = torch.Tensor(torch.randn(2,3))
kk
# Out:
#  0.5960  1.9048  1.1163
# -0.7776  1.7256  0.4337
# [torch.DoubleTensor of size 2x3]

# %%
import json
import numpy as np
labels_file = open('labels.json').read()
labels = json.loads(labels_file)

classes = labels 

print(classes["1"])
# Out:
# real

# %%
import torch
import numpy as np
from random import shuffle
a = torch.Tensor(2,2, 3).fill_(1)
b = torch.Tensor(2,2, 3).fill_(2)
c = torch.Tensor(2,2, 3).fill_(3)
d = torch.Tensor(2,2, 3).fill_(4)

l = [a, b, c, d]
shuffle(l)

# %%
import torchvision.transforms as transforms
help(transforms.ToTensor)
# Out:
# Help on class ToTensor in module torchvision.transforms:
#
# class ToTensor(builtins.object)
#  |  Converts a PIL.Image or numpy.ndarray (H x W x C) in the range
#  |  [0, 255] to a torch.FloatTensor of shape (C x H x W) in the range [0.0, 1.0].
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, pic)
#  |      Call self as a function.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
import cv2
from os import listdir

imagesPath = "raw/true/"
imagesArray = []

i = 0
for image_file in imagesPath:
    img = cv2.imread(image_file, 0)  
    cv2.imshow('image', 0)
    cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-d7c4ae78a2bc> in <module>()
#       8 for image_file in imagesPath:
#       9     img = cv2.imread(image_file, 0)
# ---> 10     cv2.imshow('image', 0)
#      11     cv2.waitKey(0)
#      12 cv2.destroyAllWindows()
#
# error: /io/opencv/modules/highgui/src/window.cpp:583: error: (-2) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Carbon support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function cvShowImage

# %%
help(cv2.imread)
# Out:
# Help on built-in function imread:
#
# imread(...)
#     imread(filename[, flags]) -> retval

# %%
import visdom
vis = visdom.Visdom()

trace = dict(x=[1,2,3], y=[4,5,6], marker={'color': 'red', 'symbol': 104, 'size': "10"},
                    mode="markers+lines",  text=["one","two","three"], name='1st Trace')
layout=dict(title="First Plot", xaxis={'title':'x1'}, yaxis={'title':'x2'})

vis._send(data=[trace], layout=layout, win='mywin')
# Out:
# ---------------------------------------------------------
# TypeError               Traceback (most recent call last)
# <ipython-input-10-3cdba36a9e3a> in <module>()
#       6 layout=dict(title="First Plot", xaxis={'title':'x1'}, yaxis={'title':'x2'})
#       7
# ----> 8 vis._send(data=[trace], layout=layout, win='mywin')
#
# TypeError: _send() got an unexpected keyword argument 'data'

# %%
import visdom
import numpy as np
vis = visdom.Visdom()
vis.text('Hello, world!')
vis.image(np.ones((3, 10, 10)))
# Out:
# 'pane_350b5f90caa346'

# %%
import torch.utils.data as data

# %%
help(data.BaseTransform)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-31d8cc7bbab5> in <module>()
# ----> 1 help(data.BaseTransform)
#
# AttributeError: module 'torch.utils.data' has no attribute 'BaseTransform'

# %%
import cv2
from os import listdir
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

def pil_loader():    
    images = []
    imagesPath = "raw/negative/"
    imagesNames = listdir(imagesPath)
    
    for image_name in imagesNames:
        image = Image.open(imagesPath + image_name).convert('RGB')
        images.append(image)
    
    return images

images_list = pil_loader()
image_test = np.array(images_list[0])

opencv_img = cv2.cvtColor(image_test, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(opencv_img)
plt.show()

print(type(opencv_img))
# Out:
# <class 'numpy.ndarray'>

# %%
#use imread
import numpy as np
import cv2

def cv_loader():
    images= []
    imagesPath = "raw/negative/"
    imagesNames = listdir(imagesPath)

    for image_name in imagesNames:
        image = cv2.imread(imagesPath + image_name, 1)
        images.append(image)
    
    return images

cv_imgs = cv_loader()
test_img = cv_imgs[0]

#show with imshow
cv2.imshow('test', test_img)
cv.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-23-71526e0c9e7b> in <module>()
#      18
#      19 #show with imshow
# ---> 20 cv2.imshow('test', test_img)
#      21 cv.waitKey(0)
#      22 cv2.destroyAllWindows()
#
# error: /io/opencv/modules/highgui/src/window.cpp:583: error: (-2) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Carbon support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function cvShowImage

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=0, releaselevel='final', serial=0)

# %%
import rospy
from sensor_msgs.msg import Image
msg = Image()
help(rospy.Time)
# help(msg.header)
